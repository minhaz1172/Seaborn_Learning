# %% [markdown]
# <a href="https://colab.research.google.com/github/minhaz1172/Seaborn_Learning/blob/main/Scatter_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips)
plt.show()

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips,hue="time")
plt.show()

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips,hue="time",style="time")
plt.show()

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips,hue="time",style="time",size="size",palette="deep")
plt.show()
